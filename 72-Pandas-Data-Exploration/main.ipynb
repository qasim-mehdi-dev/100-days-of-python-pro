# %%
60 *5

# %%
import pandas as pd

df = pd.read_csv("salaries_by_college_major.csv")
df.head()

# %%
import pandas as pd

df = pd.read_csv('/salaries_by_college_major.csv')
df.head()

# %%
df.shape

# %%
df.columns

# %%
df.isna()

# %%
df.tail()

# %%
clean_df = df.dropna()
clean_df.tail()

# %%
clean_df['Starting Median Salary']

# %%
clean_df['Starting Median Salary'].max()

# %%
clean_df['Starting Median Salary'].idmax()

# %%
clean_df['Starting Median Salary'].idxmax()

# %%
clean_df['Undergraduate Major'].loc[clean_df['Starting Median Salary'].idxmax()]

# %%
clean_df.loc[43]

# %%
spread_col = clean_df['Mid-Career 90th Percentile Salary'] - clean_df['Mid-Career 10th Percentile Salary']
clean_df.insert(1, 'Spread', spread_col)
clean_df.head()

# %%
low_risk = clean_df[['Undergraduate Major', 'Spread']].sort_values('Spread')
low_risk.head()

# %%
high_potential = clean_df[['Undergraduate Major', 'Spread']].sort_values('Spread', ascending=False)
high_potential.head()

# %%
clean_df.groupby('Group').count()

# %%
clean_df.groupby('Group').mean()

# %%
clean_df.groupby('Group').mean(numeric_only=True)

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %%
pd.options.display.float_format = '{:,.2f}'.format
clean_df.groupby('Group').mean(numeric_only=True)
